# %% [markdown]
# # Titre du document

# %% [markdown]
# Voici  comment on écrit une formule mathématique
# $e^{i\pi} + 1 = 0$
#
# $y=mx+b$

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('bmi_and_life_expectancy.csv')
df.head()
# Out:
#        Country  Life expectancy       BMI
# 0  Afghanistan             52.8  20.62058
# 1      Albania             76.8  26.44657
# 2      Algeria             75.5  24.59620
# 3      Andorra             84.6  27.63048
# 4       Angola             56.7  22.25083

# %%
model = LinearRegression()
model.fit(df[['Life expectancy']], df[['BMI']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print (type(df['Life expectancy']), type(df[['Life expectancy']]))
# Out:
# <class 'pandas.core.series.Series'> <class 'pandas.core.frame.DataFrame'>

# %%
#model.predict(df[['Life expectancy']])

# %%
plt.scatter(df[['Life expectancy']], df[['BMI']])
plt.plot(df[['Life expectancy']], model.predict(df[['Life expectancy']]))
